# %% [markdown]
# # Smart Water

# %%
import numpy as np
import pandas as pd

# %%
petrignano = pd.read_csv("Aquifer_Petrignano.csv", parse_dates=["Date"], index_col=["Date"])
petrignano
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-03-14                    NaN                    -22.48
# 2006-03-15                    NaN                    -22.38
# 2006-03-16                    NaN                    -22.25
# 2006-03-17                    NaN                    -22.38
# 2006-03-18                    NaN                    -22.60
# ...                           ...                       ...
# 2020-06-26                    0.0                    -25.68
# 2020-06-27                    0.0                    -25.80
# 2020-06-28                    0.0                    -25.80
# 2020-06-29                    0.0                    -25.78
# 2020-06-30                    0.0                    -25.91
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-03-14                    -22.18                       NaN
# 2006-03-15                    -22.14                       NaN
# 2006-03-16                    -22.04                       NaN
# 2006-03-17                    -22.04                       NaN
# 2006-03-18                    -22.04                       NaN
# ...                              ...                       ...
# 2020-06-26                    -25.07                      25.7
# 2020-06-27                    -25.11                      26.2
# 2020-06-28                    -25.19                      26.9
# 2020-06-29                    -25.18                      26.9
# 2020-06-30                    -25.25                      27.3
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-03-14                     NaN                    NaN
# 2006-03-15                     NaN                    NaN
# 2006-03-16                     NaN                    NaN
# 2006-03-17                     NaN                    NaN
# 2006-03-18                     NaN                    NaN
# ...                            ...                    ...
# 2020-06-26                    24.5             -29930.688
# 2020-06-27                    25.0             -31332.960
# 2020-06-28                    25.7             -32120.928
# 2020-06-29                    26.0             -30602.880
# 2020-06-30                    26.5             -31878.144
#
#             Hydrometry_Fiume_Chiascio_Petrignano
# Date
# 2006-03-14                                   NaN
# 2006-03-15                                   NaN
# 2006-03-16                                   NaN
# 2006-03-17                                   NaN
# 2006-03-18                                   NaN
# ...                                          ...
# 2020-06-26                                   2.5
# 2020-06-27                                   2.4
# 2020-06-28                                   2.4
# 2020-06-29                                   2.4
# 2020-06-30                                   2.4
#
# [5223 rows x 7 columns]

# %%
petrignano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5223 entries, 2006-03-14 to 2020-06-30
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Rainfall_Bastia_Umbra                 4199 non-null   float64
#  1   Depth_to_Groundwater_P24              5168 non-null   float64
#  2   Depth_to_Groundwater_P25              5184 non-null   float64
#  3   Temperature_Bastia_Umbra              4199 non-null   float64
#  4   Temperature_Petrignano                4199 non-null   float64
#  5   Volume_C10_Petrignano                 5025 non-null   float64
#  6   Hydrometry_Fiume_Chiascio_Petrignano  4199 non-null   float64
# dtypes: float64(7)
# memory usage: 326.4 KB

# %%
petrignano
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-03-14                    NaN                    -22.48
# 2006-03-15                    NaN                    -22.38
# 2006-03-16                    NaN                    -22.25
# 2006-03-17                    NaN                    -22.38
# 2006-03-18                    NaN                    -22.60
# ...                           ...                       ...
# 2020-06-26                    0.0                    -25.68
# 2020-06-27                    0.0                    -25.80
# 2020-06-28                    0.0                    -25.80
# 2020-06-29                    0.0                    -25.78
# 2020-06-30                    0.0                    -25.91
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-03-14                    -22.18                       NaN
# 2006-03-15                    -22.14                       NaN
# 2006-03-16                    -22.04                       NaN
# 2006-03-17                    -22.04                       NaN
# 2006-03-18                    -22.04                       NaN
# ...                              ...                       ...
# 2020-06-26                    -25.07                      25.7
# 2020-06-27                    -25.11                      26.2
# 2020-06-28                    -25.19                      26.9
# 2020-06-29                    -25.18                      26.9
# 2020-06-30                    -25.25                      27.3
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-03-14                     NaN                    NaN
# 2006-03-15                     NaN                    NaN
# 2006-03-16                     NaN                    NaN
# 2006-03-17                     NaN                    NaN
# 2006-03-18                     NaN                    NaN
# ...                            ...                    ...
# 2020-06-26                    24.5             -29930.688
# 2020-06-27                    25.0             -31332.960
# 2020-06-28                    25.7             -32120.928
# 2020-06-29                    26.0             -30602.880
# 2020-06-30                    26.5             -31878.144
#
#             Hydrometry_Fiume_Chiascio_Petrignano
# Date
# 2006-03-14                                   NaN
# 2006-03-15                                   NaN
# 2006-03-16                                   NaN
# 2006-03-17                                   NaN
# 2006-03-18                                   NaN
# ...                                          ...
# 2020-06-26                                   2.5
# 2020-06-27                                   2.4
# 2020-06-28                                   2.4
# 2020-06-29                                   2.4
# 2020-06-30                                   2.4
#
# [5223 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def corr_to_target(dataframe, target, title=None, file=None):
    plt.figure(figsize=(6,12))
    sns.set(font_scale=1)
    
    sns.heatmap(dataframe.corr()[[target]].sort_values(target, ascending=False),
               annot=True, cmap='coolwarm')
    
    if title: plt.title(f'\n{title}\n', fontsize=18)
    plt.xlabel('')
    plt.ylabel('')
    if file: plt.savefig(file, bbox_inches='tight')
    plt.show();

# %%
petrignano.isna().sum() * 100/len(petrignano)
# Out:
# Rainfall_Bastia_Umbra                   19.605591
# Depth_to_Groundwater_P24                 1.053035
# Depth_to_Groundwater_P25                 0.746697
# Temperature_Bastia_Umbra                19.605591
# Temperature_Petrignano                  19.605591
# Volume_C10_Petrignano                    3.790925
# Hydrometry_Fiume_Chiascio_Petrignano    19.605591
# dtype: float64

# %%
petrignano.sort_values(by=["Date"], inplace=True)
petrignano
# Out:
#             Rainfall_Bastia_Umbra  Depth_to_Groundwater_P24  \
# Date
# 2006-01-04                    NaN                    -22.77
# 2006-01-05                    NaN                    -22.07
# 2006-01-06                    NaN                    -22.18
# 2006-01-07                    NaN                    -23.65
# 2006-01-08                    NaN                    -24.54
# ...                           ...                       ...
# 2020-12-02                    0.0                    -25.56
# 2020-12-03                    0.0                    -25.15
# 2020-12-04                    0.0                    -25.35
# 2020-12-05                    0.6                    -24.93
# 2020-12-06                    0.0                    -25.22
#
#             Depth_to_Groundwater_P25  Temperature_Bastia_Umbra  \
# Date
# 2006-01-04                    -21.90                       NaN
# 2006-01-05                    -21.50                       NaN
# 2006-01-06                    -21.65                       NaN
# 2006-01-07                    -22.88                       NaN
# 2006-01-08                    -23.83                       NaN
# ...                              ...                       ...
# 2020-12-02                    -25.26                      10.5
# 2020-12-03                    -25.07                      10.8
# 2020-12-04                    -24.96                      16.0
# 2020-12-05                    -24.67                      19.5
# 2020-12-06                    -24.81                      19.3
#
#             Temperature_Petrignano  Volume_C10_Petrignano  \
# Date
# 2006-01-04                     NaN                    NaN
# 2006-01-05                     NaN                    NaN
# 2006-01-06                     NaN                    NaN
# 2006-01-07                     NaN                    NaN
# 2006-01-08                     NaN                    NaN
# ...                            ...                    ...
# 2020-12-02                    10.4             -28256.256
# 2020-12-03                    10.3             -26349.408
# 2020-12-04                    15.0             -28938.816
# 2020-12-05                    19.1             -21586.176
# 2020-12-06                    18.8             -28296.864
#
#             Hydrometry_Fiume_Chiascio_Petrignano
# Date
# 2006-01-04                                   NaN
# 2006-01-05                                   NaN
# 2006-01-06                                   NaN
# 2006-01-07                                   NaN
# 2006-01-08                                   NaN
# ...                                          ...
# 2020-12-02                                   2.4
# 2020-12-03                                   2.7
# 2020-12-04                                   2.5
# 2020-12-05                                   2.4
# 2020-12-06                                   2.7
#
# [5223 rows x 7 columns]

# %%
corr_to_target(petrignano, "Depth_to_Groundwater_P24")

# %%
plt.figure(figsize=(16,9))
plt.plot(petrignano.index, petrignano["Depth_to_Groundwater_P24"]);

# %%
plt.figure(figsize=(16,9))
plt.plot(petrignano.index, petrignano["Volume_C10_Petrignano"]);

# %%
petrignano_features = petrignano[["Depth_to_Groundwater_P24", "Volume_C10_Petrignano"]]
petrignano_features
# Out:
#             Depth_to_Groundwater_P24  Volume_C10_Petrignano
# Date
# 2006-01-04                    -22.77                    NaN
# 2006-01-05                    -22.07                    NaN
# 2006-01-06                    -22.18                    NaN
# 2006-01-07                    -23.65                    NaN
# 2006-01-08                    -24.54                    NaN
# ...                              ...                    ...
# 2020-12-02                    -25.56             -28256.256
# 2020-12-03                    -25.15             -26349.408
# 2020-12-04                    -25.35             -28938.816
# 2020-12-05                    -24.93             -21586.176
# 2020-12-06                    -25.22             -28296.864
#
# [5223 rows x 2 columns]

# %%
petrignano_features.dropna(inplace=True)
petrignano_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4971 entries, 2006-01-10 to 2020-12-06
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Depth_to_Groundwater_P24  4971 non-null   float64
#  1   Volume_C10_Petrignano     4971 non-null   float64
# dtypes: float64(2)
# memory usage: 116.5 KB
# <ipython-input-12-2d4edc5c2b34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petrignano_features.dropna(inplace=True)

# %%
# number of missing days (not missing data)
len(pd.date_range(start = '2006-01-10', end = '2020-12-06' ).difference(petrignano_features.index))
# Out:
# 474

# %%
import plotly.express as px

def lineplot_slider(y, title):
    fig = px.line(petrignano_features, x=petrignano_features.index, y=y, title=title)

    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label='1y', step='year', stepmode='backward'),
                dict(count=2, label='2y', step='year', stepmode='backward'),
                dict(count=3, label='3y', step='year', stepmode='backward'),
                dict(step="all")
                ])
            )
    )
    fig.show()

# %%
lineplot_slider("Depth_to_Groundwater_P24", "Depth_to_Groundwater_P24")

# %%
timesteps = petrignano_features.index.to_numpy()
depths = petrignano_features['Depth_to_Groundwater_P24'].to_numpy()
timesteps[:10], depths[:10]
# Out:
# (array(['2006-01-10T00:00:00.000000000', '2006-01-11T00:00:00.000000000',
#         '2006-01-12T00:00:00.000000000', '2006-02-10T00:00:00.000000000',
#         '2006-02-11T00:00:00.000000000', '2006-02-12T00:00:00.000000000',
#         '2006-03-10T00:00:00.000000000', '2006-03-11T00:00:00.000000000',
#         '2006-03-12T00:00:00.000000000', '2006-04-10T00:00:00.000000000'],
#        dtype='datetime64[ns]'),
#  array([-24.82, -25.34, -26.07, -24.87, -25.36, -26.12, -24.97, -25.38,
#         -25.99, -25.01]))

# %%
split_size = int(0.8*len(depths))

X_train, y_train = timesteps[:split_size], depths[:split_size]
X_test, y_test = timesteps[split_size:], depths[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (3976, 995, 3976, 995)

# %%
plt.figure(figsize=(16,9))
plt.plot(X_train, y_train)
plt.plot(X_test, y_test);

# %%
def plot_time_series(timesteps, values, format=".",start=0, end=None, label=None):
#     plt.figure(figsize=(10, 7))
    plt.plot(timesteps[start:end], values[start:end], format, label=label)
    plt.xlabel("Time")
    plt.ylabel("Groundwater Depth from 0")
    if label:
        plt.legend(fontsize=14)
    plt.grid(True)

# %%
plt.figure(figsize=(16, 9))
plot_time_series(X_train, y_train, label="Train data")
plot_time_series(X_test, y_test, label="Test data")

# %% [markdown]
# ## Naive Forecast

# %%
len(y_test[:-1])
# Out:
# 994

# %%
y_test[-10:]
# Out:
# array([-25.39, -25.39, -24.97, -25.28, -26.  , -25.56, -25.15, -25.35,
#        -24.93, -25.22])

# %%
naive_forecast = y_test[:-1]
naive_forecast[-10:]
# Out:
# array([-25.43, -25.39, -25.39, -24.97, -25.28, -26.  , -25.56, -25.15,
#        -25.35, -24.93])

# %%
plt.figure(figsize=(16, 9))
plot_time_series(X_test, y_test, label="Test data")
plot_time_series(X_test[1:], naive_forecast, label="naive forecast")

# %%
plt.figure(figsize=(16, 9))
plot_time_series(X_train, y_train, label="Train data")
plot_time_series(X_test, y_test, format="-", label="Test data")
plot_time_series(X_test[1:], naive_forecast, format="-", label="naive forecast")

# %%
import tensorflow as tf

# %%
def mean_absolute_scaled_error(y_true, y_pred): 
    mae = tf.reduce_mean(tf.abs(y_true-y_pred))
    mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:]-y_pred[:-1]))
    return mae/mae_naive_no_season

def evaluate_preds(y_true, y_pred):
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)
    
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred)
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
    rmse = tf.sqrt(mse)
    mase = mean_absolute_scaled_error(y_true, y_pred)
    if mse.ndim > 0:
        mse = tf.reduce_mean(mse)
        mae = tf.reduce_mean(mae)
        mape = tf.reduce_mean(mape)
        rmse = tf.reduce_mean(rmse)
        mase = tf.reduce_mean(mase)
    
    metrics = {
        "Mean Absolute Error": mae.numpy(), 
        "Mean Squared Error": mse.numpy(), 
        "Root Mean Squared Error": rmse.numpy(), 
        "Mean Absolute Percentage Error": mape.numpy(),
        "Mean Absolute Scaled Error": mase.numpy()
    }
    return metrics

# %%
mean_absolute_scaled_error(y_test[1:], naive_forecast).numpy()
# Out:
# 0.6515391882474605

# %%
naive_result = evaluate_preds(y_test[1:], naive_forecast)
naive_result
# Out:
# {'Mean Absolute Error': 0.30649894,
#  'Mean Squared Error': 0.29630473,
#  'Root Mean Squared Error': 0.5443388,
#  'Mean Absolute Percentage Error': 1.1841155,
#  'Mean Absolute Scaled Error': 0.65153915}

# %% [markdown]
# ## Dense model

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
def get_labelled_window(x, horizon=HORIZON):
    return x[:, :-horizon], x[:, -horizon:]

def make_windows(x, window_size=WINDOW_SIZE, horizon=HORIZON):
    window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
    window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T
    windowed_array = x[window_indexes]
    windows, labels = get_labelled_window(windowed_array, horizon=horizon)
    return windows, labels

# %%
len(depths)
# Out:
# 4971

# %%
depths
# Out:
# array([-24.82, -25.34, -26.07, ..., -25.35, -24.93, -25.22])

# %%
full_windows, full_labels = make_windows(depths)
len(full_windows), len(full_labels)
# Out:
# (4964, 4964)

# %%
def make_train_test_splits(windows, horizons, test_size=0.2):
    split_size = int(len(windows) * (1-test_size))
    train_windows = windows[:split_size]
    train_horizons = horizons[:split_size]
    test_windows = windows[split_size:]
    test_horizons = horizons[split_size:]
    return train_windows, test_windows, train_horizons, test_horizons

# %%
train_windows, test_windows, train_horizons, test_horizons = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_horizons), len(test_horizons)
# Out:
# (3971, 993, 3971, 993)

# %%
import os

def create_model_checkpoint(model_name, save_path="C:/Users/nrpra/Documents/vscode_py/model_expereiments"):
    return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), 
                                             verbose=0, save_best_only=True, monitor="val_loss")

# %%
from tensorflow.keras import layers

train_features = tf.data.Dataset.from_tensor_slices(train_windows)
train_target = tf.data.Dataset.from_tensor_slices(train_horizons)
train_dataset = tf.data.Dataset.zip((train_features, train_target))
train_dataset = train_dataset.batch(1024).prefetch(tf.data.experimental.AUTOTUNE)

test_features = tf.data.Dataset.from_tensor_slices(test_windows)
test_target = tf.data.Dataset.from_tensor_slices(test_horizons)
test_dataset = tf.data.Dataset.zip((test_features, test_target))
test_dataset = test_dataset.batch(1024).prefetch(tf.data.experimental.AUTOTUNE)

train_dataset, test_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 7), (None, 1)), types: (tf.float64, tf.float64)>,
#  <PrefetchDataset shapes: ((None, 7), (None, 1)), types: (tf.float64, tf.float64)>)

# %%
model_dense = tf.keras.Sequential([
    layers.Dense(128, activation="relu"), 
    layers.Dense(HORIZON, activation="linear")
])

model_dense.compile(loss="mae", 
                   optimizer=tf.keras.optimizers.Adam())

model_dense.fit(train_dataset, epochs=100, verbose=1, validation_data=test_dataset, 
               callbacks=[create_model_checkpoint("model_dense")])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 1/4 [======>.......................] - ETA: 0s - loss: 31.1342WARNING:tensorflow:From C:\Users\nrpra\ML\projects\env\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\nrpra\ML\projects\env\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 191ms/step - loss: 25.5770 - val_loss: 20.9910
# Epoch 2/100
# 1/4 [======>.......................] - ETA: 0s - loss: 23.9269INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 172ms/step - loss: 19.1053 - val_loss: 14.5144
# Epoch 3/100
# 1/4 [======>.......................] - ETA: 0s - loss: 16.5531INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 152ms/step - loss: 12.4571 - val_loss: 7.8291
# Epoch 4/100
# 1/4 [======>.......................] - ETA: 0s - loss: 8.9477INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 181ms/step - loss: 5.6156 - val_loss: 1.1390
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8308 - val_loss: 3.7985
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 4.1882 - val_loss: 3.9777
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 3.3450 - val_loss: 1.5230
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2100 - val_loss: 1.6874
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9888 - val_loss: 1.8007
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 2.0702INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 153ms/step - loss: 1.4154 - val_loss: 0.5808
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0977 - val_loss: 1.1251
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0557 - val_loss: 0.6180
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9501 - val_loss: 0.7748
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8361 - val_loss: 0.6953
# Epoch 15/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.8998INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 179ms/step - loss: 0.8479 - val_loss: 0.5385
# Epoch 16/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7365INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 148ms/step - loss: 0.7805 - val_loss: 0.5147
# Epoch 17/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7554 - val_loss: 0.5289
# Epoch 18/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7345 - val_loss: 0.5642
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7437 - val_loss: 0.5345
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7275 - val_loss: 0.5545
# Epoch 21/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7346 - val_loss: 0.5209
# Epoch 22/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7192 - val_loss: 0.5367
# Epoch 23/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.
# Epoch 72/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6184 - val_loss: 0.4542
# Epoch 73/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6012INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 154ms/step - loss: 0.6165 - val_loss: 0.4534
# Epoch 74/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5987INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6137 - val_loss: 0.4513
# Epoch 75/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5939INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 181ms/step - loss: 0.6105 - val_loss: 0.4496
# Epoch 76/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5911INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 178ms/step - loss: 0.6081 - val_loss: 0.4474
# Epoch 77/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5881INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6058 - val_loss: 0.4465
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6051 - val_loss: 0.4472
# Epoch 79/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6046 - val_loss: 0.4487
# Epoch 80/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5886INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 178ms/step - loss: 0.6027 - val_loss: 0.4455
# Epoch 81/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5840INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 158ms/step - loss: 0.5992 - val_loss: 0.4421
# Epoch 82/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5795INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5963 - val_loss: 0.4411
# Epoch 83/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5957 - val_loss: 0.4413
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5951 - val_loss: 0.4425
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5956 - val_loss: 0.4448
# Epoch 86/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5948 - val_loss: 0.4432
# Epoch 87/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5926 - val_loss: 0.4419
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5916 - val_loss: 0.4439
# Epoch 89/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5789INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 152ms/step - loss: 0.5899 - val_loss: 0.4392
# Epoch 90/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5724INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 179ms/step - loss: 0.5862 - val_loss: 0.4377
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5868 - val_loss: 0.4429
# Epoch 92/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5766INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 152ms/step - loss: 0.5857 - val_loss: 0.4366
# Epoch 93/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5679INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 178ms/step - loss: 0.5813 - val_loss: 0.4350
# Epoch 94/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5818 - val_loss: 0.4397
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5819 - val_loss: 0.4394
# Epoch 96/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5709INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 152ms/step - loss: 0.5791 - val_loss: 0.4329
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5767 - val_loss: 0.4350
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5764 - val_loss: 0.4362
# Epoch 99/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5750 - val_loss: 0.4348
# Epoch 100/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5642INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense\assets
# 4/4 [==============================] - 1s 182ms/step - loss: 0.5725 - val_loss: 0.4299

# %%
model_dense = tf.keras.models.load_model("model_expereiments/model_dense/")
model_dense.evaluate(test_dataset)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.4299
# 0.429931104183197

# %%
def make_preds(model, input_data):
    forecast = model.predict(input_data)
    return tf.squeeze(forecast)

# %%
model_dense_preds = make_preds(model_dense, test_windows)
model_dense_preds[:10]
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([-27.116611, -27.1759  , -25.819366, -25.273563, -24.240078,
#        -23.653816, -23.739788, -23.811192, -24.533562, -25.413734],
#       dtype=float32)>

# %%
offset = 400
plt.figure(figsize=(10,7))
plot_time_series(X_test[-len(test_windows):], test_horizons[:, 0], format="-", start=offset, label="Test data")
plot_time_series(X_test[-len(test_windows):], model_dense_preds, format="-", start=offset, label="Preds data")

# %%
model_dense_result = evaluate_preds(tf.squeeze(test_horizons), model_dense_preds)
model_dense_result
# Out:
# {'Mean Absolute Error': 0.42993116,
#  'Mean Squared Error': 0.48182198,
#  'Root Mean Squared Error': 0.694134,
#  'Mean Absolute Percentage Error': 1.6614221,
#  'Mean Absolute Scaled Error': 0.7833883}

# %% [markdown]
# ## Dense model (window=90, horizon=30)

# %%
WINDOW_SIZE = 90
HORIZON = 30

# %%
full_windows, full_labels = make_windows(depths, window_size=WINDOW_SIZE, horizon=HORIZON)
full_windows[:3], full_labels[:3]
# Out:
# (array([[-24.82, -25.34, -26.07, -24.87, -25.36, -26.12, -24.97, -25.38,
#          -25.99, -25.01, -25.47, -26.01, -25.09, -25.4 , -26.07, -25.14,
#          -25.39, -25.94, -25.15, -25.44, -25.87, -25.17, -25.62, -25.95,
#          -25.18, -25.65, -25.95, -24.73, -24.77, -24.8 , -24.85, -25.21,
#          -26.76, -28.15, -29.93, -30.36, -30.59, -30.69, -31.13, -27.18,
#          -27.1 , -27.15, -27.24, -27.19, -27.18, -27.1 , -27.25, -27.21,
#          -27.31, -27.27, -27.26, -27.36, -27.4 , -27.32],
#         [-26.78, -26.92, -26.68, -27.47, -27.33, -27.16, -26.3 , -26.76,
#          -28.15, -29.93, -30.36, -30.59, -30.69, -31.13, -27.18, -27.1 ,
#          -27.15, -27.24, -27.19, -27.18, -27.1 , -27.25, -27.21, -27.31,
#          -27.27, -27.26, -27.36, -27.4 , -27.32, -27.39]]))

# %%
train_windows, test_windows, train_horizons, test_horizons = make_train_test_splits(full_windows, full_labels)
train_windows.shape, test_windows.shape, train_horizons.shape, test_horizons.shape
# Out:
# ((3881, 90), (971, 90), (3881, 30), (971, 30))

# %%
train_features = tf.data.Dataset.from_tensor_slices(train_windows)
train_target = tf.data.Dataset.from_tensor_slices(train_horizons)
train_dataset = tf.data.Dataset.zip((train_features, train_target))
train_dataset = train_dataset.batch(128).prefetch(tf.data.experimental.AUTOTUNE)

test_features = tf.data.Dataset.from_tensor_slices(test_windows)
test_target = tf.data.Dataset.from_tensor_slices(test_horizons)
test_dataset = tf.data.Dataset.zip((test_features, test_target))
test_dataset = test_dataset.batch(128).prefetch(tf.data.experimental.AUTOTUNE)

train_dataset, test_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 90), (None, 30)), types: (tf.float64, tf.float64)>,
#  <PrefetchDataset shapes: ((None, 90), (None, 30)), types: (tf.float64, tf.float64)>)

# %%
model_dense2 = tf.keras.Sequential([
    layers.Dense(128, activation="relu"), 
    layers.Dense(HORIZON, activation="linear")
])

model_dense2.compile(loss="mae", 
                   optimizer=tf.keras.optimizers.Adam())

model_dense2.fit(train_dataset, epochs=100, verbose=1, validation_data=test_dataset, 
               callbacks=[create_model_checkpoint("model_dense2")])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer dense_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#  1/31 [..............................] - ETA: 0s - loss: 28.8983INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 27ms/step - loss: 9.4644 - val_loss: 1.8776
# Epoch 2/100
#  1/31 [..............................] - ETA: 0s - loss: 2.1670INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.9602 - val_loss: 1.5026
# Epoch 3/100
# 13/31 [===========>..................] - ETA: 0s - loss: 1.4191INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 26ms/step - loss: 1.6527 - val_loss: 1.2705
# Epoch 4/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.6405 - val_loss: 1.3078
# Epoch 5/100
#  1/31 [..............................] - ETA: 0s - loss: 1.5731INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 22ms/step - loss: 1.6078 - val_loss: 1.2342
# Epoch 6/100
#  1/31 [..............................] - ETA: 0s - loss: 1.5153INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 26ms/step - loss: 1.5872 - val_loss: 1.2313
# Epoch 7/100
#  1/31 [..............................] - ETA: 0s - loss: 1.5045INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.5732 - val_loss: 1.2074
# Epoch 8/100
#  1/31 [..............................] - ETA: 0s - loss: 1.4840INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.5539 - val_loss: 1.2071
# Epoch 9/100
#  1/31 [..............................] - ETA: 0s - loss: 1.4915INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.5425 - val_loss: 1.1881
# Epoch 10/100
# 31/31 [==============================] - 0s 1ms/step - loss: 1.5232 - val_loss: 1.1998
# Epoch 11/100
#  1/31 [..............................] - ETA: 0s - loss: 1.4863INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.5139 - val_loss: 1.1678
# Epoch 12/100
#  1/31 [..............................] - ETA: 0s - loss: 1.4612INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.4929 - val_loss: 1.1639
# Epoch 13/100
#  1/31 [..............................] - ETA: 0s - loss: 1.4524INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1
FO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.1212 - val_loss: 0.8299
# Epoch 63/100
#  1/31 [..............................] - ETA: 0s - loss: 1.1018INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.1110 - val_loss: 0.8096
# Epoch 64/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0808INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 20ms/step - loss: 1.1012 - val_loss: 0.7984
# Epoch 65/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0688INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.0920 - val_loss: 0.7954
# Epoch 66/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0627INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.0890 - val_loss: 0.7934
# Epoch 67/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0573INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.0826 - val_loss: 0.7894
# Epoch 68/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0774 - val_loss: 0.7921
# Epoch 69/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0541INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 1.0735 - val_loss: 0.7882
# Epoch 70/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0500INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 20ms/step - loss: 1.0675 - val_loss: 0.7868
# Epoch 71/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0501INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 1.0650 - val_loss: 0.7801
# Epoch 72/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0569 - val_loss: 0.8133
# Epoch 73/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0606 - val_loss: 0.8573
# Epoch 74/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0595 - val_loss: 0.8563
# Epoch 75/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0563 - val_loss: 0.8015
# Epoch 76/100
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0343 - val_loss: 0.8299
# Epoch 77/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0473 - val_loss: 0.8372
# Epoch 78/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0378 - val_loss: 0.8633
# Epoch 79/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0493 - val_loss: 0.8693
# Epoch 80/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0411 - val_loss: 0.8353
# Epoch 81/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0407 - val_loss: 0.8380
# Epoch 82/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0363 - val_loss: 0.8472
# Epoch 83/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0317 - val_loss: 0.8202
# Epoch 84/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0277 - val_loss: 0.8318
# Epoch 85/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0229 - val_loss: 0.8149
# Epoch 86/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0125 - val_loss: 0.8150
# Epoch 87/100
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0098 - val_loss: 0.7947
# Epoch 88/100
# 31/31 [==============================] - 0s 1ms/step - loss: 1.0024 - val_loss: 0.7910
# Epoch 89/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0168INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 26ms/step - loss: 0.9969 - val_loss: 0.7755
# Epoch 90/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9894 - val_loss: 0.7793
# Epoch 91/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9875 - val_loss: 0.7780
# Epoch 92/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0076INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 26ms/step - loss: 0.9859 - val_loss: 0.7739
# Epoch 93/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0053INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 0.9828 - val_loss: 0.7724
# Epoch 94/100
#  1/31 [..............................] - ETA: 0s - loss: 1.0038INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 26ms/step - loss: 0.9793 - val_loss: 0.7675
# Epoch 95/100
#  1/31 [..............................] - ETA: 0s - loss: 0.9971INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 21ms/step - loss: 0.9759 - val_loss: 0.7671
# Epoch 96/100
#  1/31 [..............................] - ETA: 0s - loss: 0.9985INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_dense2\assets
# 31/31 [==============================] - 1s 25ms/step - loss: 0.9741 - val_loss: 0.7646
# Epoch 97/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9695 - val_loss: 0.7950
# Epoch 98/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9740 - val_loss: 0.7696
# Epoch 99/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9682 - val_loss: 0.7882
# Epoch 100/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.9702 - val_loss: 0.7697

# %%
model_dense2 = tf.keras.models.load_model("model_expereiments/model_dense2/")
model_dense2.evaluate(test_dataset)
# Out:
# 8/8 [==============================] - 0s 995us/step - loss: 0.7646
# 0.7646239995956421

# %%
model_dense2_preds = make_preds(model_dense2, test_windows)
model_dense2_preds[:5]
# Out:
# <tf.Tensor: shape=(5, 30), dtype=float32, numpy=
# array([[-25.776785, -26.356361, -26.000784, -26.990667, -25.769745,
#         -26.617147, -26.033123, -26.169176, -25.789188, -25.435865,
#         -23.889734, -23.953127, -24.467836, -25.071325, -25.404064,
#         -26.230124, -25.561235, -26.886646, -26.7904  , -26.402702,
#         -26.772655, -26.573614, -26.306467, -26.681047, -26.590351,
#         -26.996918, -26.204695, -26.618004, -26.325645, -26.486286],
#        [-25.657476, -26.611267, -26.190918, -26.868677, -25.702036,
#         -26.388977, -25.52625 , -26.256231, -25.407652, -25.674673,
#         -24.191603, -24.539923, -25.316187, -25.510378, -25.773746,
#         -25.8341  , -26.24672 , -26.00435 , -26.864967, -26.834906,
#         -26.205536, -26.311434, -26.326357, -27.275743, -26.960184,
#         -26.791628, -26.10579 , -26.501839, -26.148914, -26.950298],
#        [-25.940727, -26.171316, -26.132837, -26.707752, -25.52225 ,
#         -25.836502, -25.253374, -25.69846 , -25.36635 , -25.76371 ,
#         -24.77047 , -25.172571, -25.763754, -25.868004, -26.348726,
#         -26.157146, -25.911325, -26.395466, -25.864399, -26.299587,
#         -26.425264, -26.532202, -26.03269 , -26.658226, -27.076818,
#         -26.916128, -26.189056, -26.545187, -26.259178, -26.624186],
#        [-26.1281  , -25.79807 , -25.601055, -26.654234, -25.034637,
#         -25.268236, -24.915236, -25.095045, -24.989038, -25.819963,
#         -24.857622, -25.754145, -26.734982, -26.45907 , -26.385744,
#         -26.127705, -26.40176 , -26.046099, -25.495752, -26.312132,
#         -26.145073, -25.885786, -25.849945, -26.804234, -27.012512,
#         -26.706146, -26.278881, -26.662775, -26.07602 , -26.456867],
#        [-26.16881 , -25.283827, -25.479609, -26.122171, -24.506084,
#         -24.35825 , -23.98798 , -24.638649, -24.847492, -26.414799,
#         -25.557367, -25.89382 , -26.614496, -26.609468, -26.750536,
#         -26.296782, -26.322912, -26.225286, -25.643402, -26.0824  ,
#         -25.918356, -26.19199 , -25.459839, -27.006525, -26.983978,
#         -26.368523, -26.111456, -27.160332, -26.415419, -26.605072]],
#       dtype=float32)>

# %%
offset = 400
plt.figure(figsize=(10,7))
plot_time_series(X_test[-len(test_windows):], test_horizons[:, 0], format="-", start=offset, label="Test data")
plot_time_series(X_test[-len(test_windows):], np.mean(model_dense2_preds, axis=1), format="-", start=offset, label="Preds data")

# %%
model_dense2_result = evaluate_preds(tf.squeeze(test_horizons), model_dense2_preds)
model_dense2_result
# Out:
# {'Mean Absolute Error': 0.76462394,
#  'Mean Squared Error': 0.89496285,
#  'Root Mean Squared Error': 0.9039774,
#  'Mean Absolute Percentage Error': 2.9163616,
#  'Mean Absolute Scaled Error': 0.9902714}

# %% [markdown]
# ## LSTM model

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
full_windows, full_labels = make_windows(depths, window_size=WINDOW_SIZE, horizon=HORIZON)
train_windows, test_windows, train_horizons, test_horizons = make_train_test_splits(full_windows, full_labels)

# %%
from tensorflow.keras import layers

train_features = tf.data.Dataset.from_tensor_slices(train_windows)
train_target = tf.data.Dataset.from_tensor_slices(train_horizons)
train_dataset = tf.data.Dataset.zip((train_features, train_target))
train_dataset = train_dataset.batch(1024).prefetch(tf.data.experimental.AUTOTUNE)

test_features = tf.data.Dataset.from_tensor_slices(test_windows)
test_target = tf.data.Dataset.from_tensor_slices(test_horizons)
test_dataset = tf.data.Dataset.zip((test_features, test_target))
test_dataset = test_dataset.batch(1024).prefetch(tf.data.experimental.AUTOTUNE)

train_dataset, test_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 7), (None, 1)), types: (tf.float64, tf.float64)>,
#  <PrefetchDataset shapes: ((None, 7), (None, 1)), types: (tf.float64, tf.float64)>)

# %%
tf.random.set_seed(42)

inputs = layers.Input(shape=(7))
x = layers.Lambda(lambda x: tf.expand_dims(x, axis=1))(inputs)
# x = layers.LSTM(128, return_sequences=True)(x)
x = layers.LSTM(128, activation="relu")(x)
# x = layers.Dense(32, activation="relu")(x)
outputs = layers.Dense(HORIZON)(x)
model_lstm = tf.keras.Model(inputs, outputs)

model_lstm.compile(loss="mae", 
               optimizer=tf.keras.optimizers.Adam())

model_lstm.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 7)]               0
# _________________________________________________________________
# lambda (Lambda)              (None, 1, 7)              0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               69632
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 69,761
# Trainable params: 69,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_lstm.fit(train_dataset, epochs=100, verbose=1, validation_data=test_dataset, 
               callbacks=[create_model_checkpoint("model_lstm")])
# Out:
# Epoch 1/100
# 1/4 [======>.......................] - ETA: 0s - loss: 30.2765INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 982ms/step - loss: 26.1801 - val_loss: 24.1273
# Epoch 2/100
# 1/4 [======>.......................] - ETA: 0s - loss: 27.4363INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 925ms/step - loss: 23.6578 - val_loss: 21.6080
# Epoch 3/100
# 1/4 [======>.......................] - ETA: 0s - loss: 24.6016INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 888ms/step - loss: 21.0023 - val_loss: 18.7024
# Epoch 4/100
# 1/4 [======>.......................] - ETA: 0s - loss: 21.3368INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 3s 872ms/step - loss: 17.8345 - val_loss: 15.0310
# Epoch 5/100
# 1/4 [======>.......................] - ETA: 0s - loss: 17.1499INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 997ms/step - loss: 13.7428 - val_loss: 10.1967
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 11.5154INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 878ms/step - loss: 8.3705 - val_loss: 4.0820
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 4.3246INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 884ms/step - loss: 2.2984 - val_loss: 2.4463
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 3.2533 - val_loss: 3.4217
# Epoch 9/100
# 1/4 [======>.......................] - ETA: 0s - loss: 4.3068INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 916ms/step - loss: 2.9531 - val_loss: 1.3029
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2921 - val_loss: 1.4988
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.7633 - val_loss: 1.6138
# Epoch 12/100
# 1/4 [======>.......................] - ETA: 0s - loss: 1.6111INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 994ms/step - loss: 1.3378 - val_loss: 0.5196
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9377 - val_loss: 0.9408
# Epoch 14/100
# 1/4 [======>.......................] - ETA: 0s - loss: 1.3622INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 882ms/step - loss: 1.0579 - val_loss: 0.5158
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9091 - val_loss: 0.7792
# Epoch 16/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8668 - val_loss: 0.5373
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8404 - val_loss: 0.5881
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8621 - val_loss: 0.5897
# Epoch 19/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7290INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 986ms/step - loss: 0.8110 - val_loss: 0.5113
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7751 - val_loss: 0.5332
# Epoch 21/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8079 - val_loss: 0.5210
# Epoch 22/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7280INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 956ms/step - loss: 0.7762 - val_loss: 0.5071
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7622 - val_loss: 0.5092
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7738 - val_loss: 0.5083
# Epoch 25/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7197INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 910ms/step - loss: 0.7538 - val_loss: 0.5026
# Epoch 26/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7365INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 3s 858ms/step - loss: 0.7530 - val_loss: 0.5007
# Epoch 27/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7247INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 904ms/step - loss: 0.7482 - val_loss: 0.5000
# Epoch 28/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7112INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 902ms/step - loss: 0.7375 - val_loss: 0.4994
# Epoch 29/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7196INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 3s 869ms/step - loss: 0.7387 - val_loss: 0.4971
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7282 - val_loss: 0.4972
# Epoch 31/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.7086INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 930ms/step - loss: 0.7283 - val_loss: 0.4942
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7196 - val_loss: 0.4952
# Epoch 33/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6988INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 915ms/step - loss: 0.7195 - val_loss: 0.4915
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7111 - val_loss: 0.4926
# Epoch 35/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6877INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 975ms/step - loss: 0.7095 - val_loss: 0.4885
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7021 - val_loss: 0.4896
# Epoch 37/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6762INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 933ms/step - loss: 0.7008 - val_loss: 0.4843
# Epoch 38/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6699INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 961ms/step - loss: 0.6955 - val_loss: 0.4823
# Epoch 39/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6908 - val_loss: 0.4827
# Epoch 40/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6630INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 946ms/step - loss: 0.6879 - val_loss: 0.4799
# Epoch 41/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6592INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 892ms/step - loss: 0.6862 - val_loss: 0.4771
# Epoch 42/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6604INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 1s/step - loss: 0.6828 - val_loss: 0.4752
# Epoch 43/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.6563INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5509 - val_loss: 0.4044
# Epoch 89/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5204INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 950ms/step - loss: 0.5459 - val_loss: 0.3997
# Epoch 90/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5117INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 926ms/step - loss: 0.5436 - val_loss: 0.3983
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5420 - val_loss: 0.3994
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5420 - val_loss: 0.4001
# Epoch 93/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5112INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 999ms/step - loss: 0.5402 - val_loss: 0.3981
# Epoch 94/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5073INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 902ms/step - loss: 0.5372 - val_loss: 0.3959
# Epoch 95/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5354 - val_loss: 0.3959
# Epoch 96/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5022INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 922ms/step - loss: 0.5344 - val_loss: 0.3957
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5331 - val_loss: 0.3962
# Epoch 98/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5020INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 1s/step - loss: 0.5312 - val_loss: 0.3940
# Epoch 99/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4977INFO:tensorflow:Assets written to: C:/Users/nrpra/Documents/vscode_py/model_expereiments\model_lstm\assets
# 4/4 [==============================] - 4s 888ms/step - loss: 0.5290 - val_loss: 0.3938
# Epoch 100/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5281 - val_loss: 0.3944

# %%
model_lstm = tf.keras.models.load_model("model_expereiments/model_lstm/")
model_lstm.evaluate(test_dataset)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.3938
# 0.3937833905220032

# %%
model_lstm_preds = make_preds(model_lstm, test_windows)
model_lstm_preds[:10]
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([-27.139647, -27.197578, -25.716288, -24.720928, -23.991215,
#        -23.867775, -23.488327, -23.918242, -24.782566, -25.840023],
#       dtype=float32)>

# %%
plt.figure(figsize=(16,9))
offset=300
plot_time_series(X_test[-len(test_windows):], test_horizons[:, ], format="-", start=offset, label="Test data")
plot_time_series(X_test[-len(test_windows):], model_lstm_preds, format="-", start=offset, label="Preds data")

# %%
model_lstm_result = evaluate_preds(tf.squeeze(test_horizons), model_lstm_preds)
model_lstm_result
# Out:
# {'Mean Absolute Error': 0.39378327,
#  'Mean Squared Error': 0.42412826,
#  'Root Mean Squared Error': 0.6512513,
#  'Mean Absolute Percentage Error': 1.5232587,
#  'Mean Absolute Scaled Error': 0.74458194}

# %% [markdown]
# # Model comparison

# %%
model_results = pd.DataFrame({
    "naive model": naive_result,
    "dense model 1 horizon": model_dense_result, 
    "dense model 30 horizon": model_dense2_result, 
    "LSTM model 1 horizon": model_lstm_result
}).T
model_results
# Out:
#                         Mean Absolute Error  Mean Squared Error  \
# naive model                        0.306499            0.296305
# dense model 1 horizon              0.429931            0.481822
# dense model 30 horizon             0.764624            0.894963
# LSTM model 1 horizon               0.393783            0.424128
#
#                         Root Mean Squared Error  \
# naive model                            0.544339
# dense model 1 horizon                  0.694134
# dense model 30 horizon                 0.903977
# LSTM model 1 horizon                   0.651251
#
#                         Mean Absolute Percentage Error  \
# naive model                                   1.184116
# dense model 1 horizon                         1.661422
# dense model 30 horizon                        2.916362
# LSTM model 1 horizon                          1.523259
#
#                         Mean Absolute Scaled Error
# naive model                               0.651539
# dense model 1 horizon                     0.783388
# dense model 30 horizon                    0.990271
# LSTM model 1 horizon                      0.744582

# %%
model_results[["Mean Absolute Error"]].sort_values(by=["Mean Absolute Error"]).plot(figsize=(10,7), kind="bar");

# %% [markdown]
# # Making a predictions

# %%
full_windows.shape
# Out:
# (4964, 7)

# %%
full_labels.shape
# Out:
# (4964, 1)
